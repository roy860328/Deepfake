# %%
import pandas as pd
import numpy as np
import json

import util
# import CNN

def get_data_class(json, path):
	df_train = pd.read_json(json)
	print(df_train)
	df_trains = [df_train]

	dataProcess = util.DataProcess(df_trains, path, videoPreprocess)
	return dataProcess

def processs_data_to_json(sample_submission):
	sample_submission = sample_submission.to_json(orient='table')
# 	print(sample_submission)
    sample_submission = json.loads(sample_submission)
	print(sample_submission)
### Setting
data_size = 1
batch_size = 1
if batch_size > data_size:
	batch_size = data_size
test = True
sample_submission = pd.read_csv("sample_submission.csv")
# print(sample_submission.columns.values)
processs_data_to_json(sample_submission)
# Out:
# {"schema": {"fields":[{"name":"index","type":"integer"},{"name":"filename","type":"string"},{"name":"label","type":"integer"}],"primaryKey":["index"],"pandas_version":"0.20.0"}, "data": [{"index":0,"filename":"aassnaulhq.mp4","label":0},{"index":1,"filename":"aayfryxljh.mp4","label":0},{"index":2,"filename":"acazlolrpz.mp4","label":0},{"index":3,"filename":"adohdulfwb.mp4","label":0},{"index":4,"filename":"ahjnxtiamx.mp4","label":0},{"index":5,"filename":"ajiyrjfyzp.mp4","label":0},{"index":6,"filename":"aktnlyqpah.mp4","label":0},{"index":7,"filename":"alrtntfxtd.mp4","label":0},{"index":8,"filename":"aomqqjipcp.mp4","label":0},{"index":9,"filename":"apedduehoy.mp4","label":0},{"index":10,"filename":"apvzjkvnwn.mp4","label":0},{"index":11,"filename":"aqrsylrzgi.mp4","label":0},{"index":12,"filename":"axfhbpkdlc.mp4","label":0},{"index":13,"filename":"ayipraspbn.mp4","label":0},{"index":14,"filename":"bcbqxhziqz.mp4","label":0},{"index":15,"filename":"bcvheslzrq.mp4","label":0},{"index":16,"filename":"bdshuoldwx.mp4","label":0},{"index":17,"filename":"bfdopzvxbi.mp4","label":0},{"index":18,"filename":"bfjsthfhbd.mp4","label":0},{"index":19,"filename":"bjyaxvggle.mp4","label":0},{"index":20,"filename":"bkcyglmfci.mp4","label":0},{"index":21,"filename":"bktkwbcawi.mp4","label":0},{"index":22,"filename":"bkuzquigyt.mp4","label":0},{"index":23,"filename":"blnmxntbey.mp4","label":0},{"index":24,"filename":"blszgmxkvu.mp4","label":0},{"index":25,"filename":"bnuwxhfahw.mp4","label":0},{"index":26,"filename":"bofrwgeyjo.mp4","label":0},{"index":27,"filename":"btdxnajogv.mp4","label":0},{"index":28,"filename":"bvpeerislp.mp4","label":0},{"index":29,"filename":"bwdmzwhdnw.mp4","label":0},{"index":30,"filename":"bzvzpw